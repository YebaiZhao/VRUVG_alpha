# 17.929390  41.52407  4.186412  36.80011     8.137693    23.8905      0
# 17.948120  41.52407  4.186412  36.80011     9.115657   24.69589      0
# 17.952370  41.52407  4.186412  36.80011     9.115657   24.69589      0
# 17.969170  41.52407  4.186412  36.80011     9.929869   69.40887      0
# 17.993440  41.52407  4.186412  36.80011     10.43249   69.08406      0
# 18.018570  41.52407  4.186412  36.80011     10.93313   68.71803      0
# 18.042910  41.52407  4.186412  36.80011      12.3735   67.63583      0
#
#               CatLoc    CatEvent  LHTrigger  LRTrigger  LHGrabb  RHGrabb  \
# Timestamp
# 7.482460         NaN    CatEvent  LHTrigger  LRTrigger  LHGrabb  RHGrabb
# 7.550944           3       CatTP  LHTrigger  LRTrigger  LHGrabb  RHGrabb
# 7.598554           3         NaN        NaN        NaN      NaN      NaN
# 8.442941           3         NaN        NaN        NaN      NaN      NaN
# 8.543343           3         NaN        NaN        NaN      NaN      NaN
# 8.570373           3         NaN        NaN        NaN      NaN      NaN
# 8.696916           3         NaN        NaN        NaN      NaN      NaN
# 8.842698           3         NaN        NaN        NaN      NaN      NaN
# 17.891650          3         NaN        NaN        NaN      NaN      NaN
# 17.897750          3         NaN        NaN        NaN      NaN      NaN
# 17.903360          3         NaN        NaN        NaN      NaN      NaN
# 17.914150          3         NaN        NaN        NaN      NaN      NaN
# 17.926000  WaitForTP  CatRebrith        NaN        NaN      NaN      NaN
# 17.929390  WaitForTP         NaN        NaN        NaN      NaN      NaN
# 17.948120  WaitForTP         NaN        NaN        NaN      NaN      NaN
# 17.952370          9       CatTP        NaN        NaN      NaN      NaN
# 17.969170          9         NaN        NaN        NaN      NaN      NaN
# 17.993440          9         NaN        NaN        NaN      NaN      NaN
# 18.018570          9         NaN        NaN        NaN      NaN      NaN
# 18.042910          9         NaN        NaN        NaN      NaN      NaN
#
#            TColor    Text  Cube  Bonus   CatX   CatY   CatZ    CatType  \
# Timestamp
# 7.482460   yellow  purple  Cube  Bonus   CatX   CatY   CatZ        NaN
# 7.550944   yellow  purple  Cube     10  32.96   3.17  31.18        NaN
# 7.598554   yellow  purple   NaN     10    NaN    NaN    NaN        NaN
# 8.442941   yellow  purple   NaN     10    NaN    NaN    NaN        NaN
# 8.543343   yellow  purple   NaN     10    NaN    NaN    NaN        NaN
# 8.570373   yellow  purple   NaN     10    NaN    NaN    NaN        NaN
# 8.696916   yellow  purple   NaN     10    NaN    NaN    NaN        NaN
# 8.842698   yellow  purple   NaN     10    NaN    NaN    NaN        NaN
# 17.891650  yellow  purple   NaN     20    NaN    NaN    NaN        NaN
# 17.897750  yellow  purple   NaN     20    NaN    NaN    NaN        NaN
# 17.903360  yellow  purple   NaN     20    NaN    NaN    NaN        NaN
# 17.914150  yellow  purple   NaN     20    NaN    NaN    NaN        NaN
# 17.926000  yellow  purple   NaN     20    NaN    NaN    NaN  CubeTaker
# 17.929390  yellow  purple   NaN     20  32.96   3.17  31.18  CubeTaker
# 17.948120  yellow  purple   NaN     20  32.96   3.17  31.18  CubeTaker
# 17.952370  yellow  purple   NaN     20  41.11  3.557   38.7  CubeTaker
# 17.969170  yellow  purple   NaN     20  41.11  3.557   38.7  CubeTaker
# 17.993440  yellow  purple   NaN     20  41.11  3.557   38.7  CubeTaker
# 18.018570  yellow  purple   NaN     20  41.11  3.557   38.7  CubeTaker
# 18.042910  yellow  purple   NaN     20  41.11  3.557   38.7  CubeTaker
#
#              ForwardX    ForwardY       ForwardZ  VGType
# Timestamp
# 7.482460     ForwardX    ForwardY       ForwardZ       6
# 7.550944     ForwardX    ForwardY       ForwardZ       6
# 7.598554           -1           0  -1.192093E-07       6
# 8.442941           -1           0  -1.192093E-07       6
# 8.543343           -1           0  -1.192093E-07       6
# 8.570373           -1           0  -1.192093E-07       6
# 8.696916           -1           0  -1.192093E-07       6
# 8.842698           -1           0  -1.192093E-07       6
# 17.891650          -1           0  -1.192093E-07       6
# 17.897750   -0.942735  -0.2981565     -0.1495114       6
# 17.903360  -0.9447188  -0.2995099     -0.1334191       6
# 17.914150    -0.94411  -0.3056134      -0.123519       6
# 17.926000    -0.94411  -0.3056134      -0.123519       6
# 17.929390  -0.9451596  -0.3058313     -0.1146337       6
# 17.948120  -0.9454226   -0.309627     -0.1015252       6
# 17.952370  -0.9454226   -0.309627     -0.1015252       6
# 17.969170  -0.9468768   -0.309285    -0.08813481       6
# 17.993440  -0.9466248  -0.3117612     -0.0818953       6
# 18.018570   -0.945711    -0.31598    -0.07607663       6
# 18.042910  -0.9479254  -0.3140544    -0.05298889       6

# %%
df.CatEvent[df.CatEvent=="CatDead"]
# Out:
# Timestamp
# 23.03149     CatDead
# 39.71306     CatDead
# 57.61551     CatDead
# 74.61517     CatDead
# 163.71540    CatDead
# Name: CatEvent, dtype: object

# %%
plot(df.HeadX.loc[50:], df.HeadZ.loc[50:], label='Head')
plot(df.LHandX.loc[50:], df.LHandZ.loc[50:], label='LHand')
plot(df.RHandX.loc[50:], df.RHandZ.loc[50:], label='RHand')
legend()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-5-d64e7e76cc25> in <module>()
# ----> 1 plot(df.HeadX.loc[50:], df.HeadZ.loc[50:], label='Head')
#       2 plot(df.LHandX.loc[50:], df.LHandZ.loc[50:], label='LHand')
#       3 plot(df.RHandX.loc[50:], df.RHandZ.loc[50:], label='RHand')
#       4 legend()
#
# NameError: name 'plot' is not defined

# %%
threedee = plt.figure().gca(projection='3d')

threedee.plot(df.LHandX.loc[40:45], df.LHandZ.loc[40:45], df.LHandY.loc[40:45])
threedee.plot(df.RHandX.loc[40:45], df.RHandZ.loc[40:45], df.RHandY.loc[40:45])
threedee.plot(df.HeadX.loc[40:45], df.HeadZ.loc[40:45], df.HeadY.loc[40:45])
threedee.set_xlabel('x')
threedee.set_ylabel('y')
threedee.set_zlabel('z')
plt.show()
# Out:
# TypeErrorTraceback (most recent call last)
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\pylabtools.pyc in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     122
#     123     bytes_io = BytesIO()
# --> 124     fig.canvas.print_figure(bytes_io, **kw)
#     125     data = bytes_io.getvalue()
#     126     if fmt == 'svg':
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2214                     orientation=orientation,
#    2215                     dryrun=True,
# -> 2216                     **kwargs)
#    2217                 renderer = self.figure._cachedRenderer
#    2218                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     428             # if toolbar:
#     429             #     toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             # if toolbar:
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1297
#    1298             mimage._draw_list_compositing_images(
# -> 1299                 renderer, self, artists, self.suppressComposite)
#    1300
#    1301             renderer.close_group('figure')
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# C:\ProgramData\Anaconda2\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in draw(self, renderer)
#     299
#     300         # Then rest
# --> 301         super(Axes3D, self).draw(renderer)
#     302
#     303     def get_axis_position(self):
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2435             renderer.stop_rasterizing()
#    2436
# -> 2437         mimage._draw_list_compositing_images(renderer, self, artists)
#    2438
#    2439         renderer.close_group('axes')
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# C:\ProgramData\Anaconda2\lib\site-packages\mpl_toolkits\mplot3d\art3d.py in draw(self, renderer)
#     133     def draw(self, renderer):
#     134         xs3d, ys3d, zs3d = self._verts3d
# --> 135         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     136         self.set_data(xs, ys)
#     137         lines.Line2D.draw(self, renderer)
#
# C:\ProgramData\Anaconda2\lib\site-packages\mpl_toolkits\mplot3d\proj3d.py in proj_transform(xs, ys, zs, M)
#     170     """
#     171     vec = vec_pad_ones(xs, ys, zs)
# --> 172     return proj_transform_vec(vec, M)
#     173
#     174 def proj_transform_clip(xs, ys, zs, M):
#
# C:\ProgramData\Anaconda2\lib\site-packages\mpl_toolkits\mplot3d\proj3d.py in proj_transform_vec(vec, M)
#     136
#     137 def proj_transform_vec(vec, M):
# --> 138     vecw = np.dot(M, vec)
#     139     w = vecw[3]
#     140     # clip here..
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
df.HeadtoBoard.loc[:19.31707].plot()
df.HeadtoCat.loc[:19.31707].plot()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-7-98f27aa2127c> in <module>()
# ----> 1 df.HeadtoBoard.loc[:19.31707].plot()
#       2 df.HeadtoCat.loc[:19.31707].plot()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1925                  yerr=yerr, xerr=xerr,
#    1926                  label=label, secondary_y=secondary_y,
# -> 1927                  **kwds)
#    1928
#    1929
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1727         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1728
# -> 1729     plot_obj.generate()
#    1730     plot_obj.draw()
#    1731     return plot_obj.result
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     248     def generate(self):
#     249         self._args_adjust()
# --> 250         self._compute_plot_data()
#     251         self._setup_subplots()
#     252         self._make_plot()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     363         if is_empty:
#     364             raise TypeError('Empty {0!r}: no numeric data to '
# --> 365                             'plot'.format(numeric_data.__class__.__name__))
#     366
#     367         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D

# Create some random data, I took this piece from here:
# http://matplotlib.org/mpl_examples/mplot3d/scatter3d_demo.py

# Create a figure and a 3D Axes
fig = plt.figure()
ax = Axes3D(fig)

# Create an init function and the animate functions.
# Both are explained in the tutorial. Since we are changing
# the the elevation and azimuth and no objects are really
# changed on the plot we don't have to return anything from
# the init and animate function. (return value is explained
# in the tutorial.
def init():
    ax.scatter(df.HeadX.loc[df.index[500]], df.HeadZ.loc[df.index[500]], df.HeadY.loc[df.index[500]], c="goldenrod", alpha=0.6)
    return fig,

def animate(i):
    ax.view_init(elev=10., azim=i)
    return fig,

# Animate
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=360, interval=20, blit=True)
# Save
#anim.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])

# %%
import imageio
imageio.plugins.ffmpeg.download()
import matplotlib.pyplot as plt
import numpy as np
from moviepy.editor import VideoClip
from moviepy.video.io.bindings import mplfig_to_npimage

fig, ax = plt.subplots()
ax=p3.Axes3D(fig)
ax.set_xlim3d

starttime = 17

def make_frame(t):
    ax.clear()
    ax.plot(df.HeadX.loc[df.index[t]], df.HeadZ.loc[df.index[t]], df.HeadY.loc[df.index[t]])
    t=t+1
    return mplfig_to_npimage(fig)

    

animation = VideoClip(make_frame, duration=2)
animation.write_gif('matplotlib.gif', fps=20)

# %%
print(df.ix[308.92310].LHandZ)
df.index==308.92310

# %%
for i, val in enumerate(df.index):
    if val == 308.92310:
        print(i)
        print df.index[i]
